# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)

import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4
# Out:
# 1.13.1
# [WinError 2] 系統找不到指定的檔案。: 'cupoy_cv_part4'
# E:\GitHub\1st-DL-CVMarathon\Homework\cupoy_cv_part4

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               1049088
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 3s 1ms/step - loss: 0.0067 - val_loss: 0.0022
#
# Epoch 00001: val_loss improved from inf to 0.00218, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 0.0017 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00218 to 0.00188, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss did not improve from 0.00188
# Epoch 4/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00188
# Epoch 5/150
# 1712/1712 [==============================] - 0s 201us/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00005: val_loss improved from 0.00188 to 0.00187, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00187 to 0.00175, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 8.8402e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00175 to 0.00159, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 7.7021e-04 - val_loss: 0.0015
#
# Epoch 00008: val_loss improved from 0.00159 to 0.00146, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 6.8661e-04 - val_loss: 0.0014
#
# Epoch 00009: val_loss improved from 0.00146 to 0.00141, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 6.0751e-04 - val_loss: 0.0013
#
# Epoch 00010: val_loss improved from 0.00141 to 0.00127, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 5.4836e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00127 to 0.00115, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 5.0483e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00115 to 0.00113, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 4.6578e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00113 to 0.00106, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 4.4945e-04 - val_loss: 0.0011
#
# Epoch 00014: val_loss did not improve from 0.00106
# Epoch 15/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 4.1229e-04 - val_loss: 9.9812e-04
#
# Epoch 00015: val_loss improved from 0.00106 to 0.00100, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 4.0333e-04 - val_loss: 9.7302e-04
#
# Epoch 00016: val_loss improved from 0.00100 to 0.00097, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 3.8969e-04 - val_loss: 9.4390e-04
#
# Epoch 00017: val_loss improved from 0.00097 to 0.00094, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 3.7959e-04 - val_loss: 9.3815e-04
#
# Epoch 00018: val_loss improved from 0.00094 to 0.00094, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 3.5880e-04 - val_loss: 9.0851e-04
#
# Epoch 00019: val_loss improved from 0.00094 to 0.00091, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 3.4491e-04 - val_loss: 9.3086e-04
#
# Epoch 00020: val_loss did not improve from 0.00091
# Epoch 21/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 3.2844e-04 - val_loss: 8.9533e-04
#
# Epoch 00021: val_loss improved from 0.00091 to 0.00090, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 3.1241e-04 - val_loss: 8.5273e-04
#
# Epoch 00022: val_loss improved from 0.00090 to 0.00085, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 3.0081e-04 - val_loss: 8.7765e-04
#
# Epoch 00023: val_loss did not improve from 0.00085
# Epoch 24/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 2.8932e-04 - val_loss: 8.3567e-04
#
# Epoch 00024: val_loss improved from 0.00085 to 0.00084, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 2.8370e-04 - val_loss: 8.7153e-04
#
# Epoch 00025: val_loss did not improve from 0.00084
# Epoch 26/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 2.9272e-04 - val_loss: 9.0192e-04
#
# Epoch 00026: val_loss did not improve from 0.00084
# Epoch 27/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 2.7427e-04 - val_loss: 8.6084e-04
#
# Epoch 00027: val_loss did not improve from 0.00084
# Epoch 28/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 2.6273e-04 - val_loss: 8.3989e-04
#
# Epoch 00028: val_loss did not improve from 0.00084
# Epoch 29/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 2.5926e-04 - val_loss: 8.2122e-04
#
# Epoch 00029: val_loss improved from 0.00084 to 0.00082, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 2.5958e-04 - val_loss: 8.4154e-04
#
# Epoch 00030: val_loss did not improve from 0.00082
# Epoch 31/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 2.5427e-04 - val_loss: 8.3550e-04
#
# Epoch 00031: val_loss did not improve from 0.00082
# Epoch 32/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 2.5086e-04 - val_loss: 8.2904e-04
#
# Epoch 00032: val_loss did not improve from 0.00082
# Epoch 33/150
# 1712/1712 [==============================] - 0s 201us/step - loss: 2.3888e-04 - val_loss: 8.0995e-04
#
# Epoch 00033: val_loss improved from 0.00082 to 0.00081, saving model to best_weights.h5
# Epoch 34/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 2.3141e-04 - val_loss: 8.7233e-04
#
# Epoch 00034: val_loss did not improve from 0.00081
# Epoch 35/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 2.4628e-04 - val_loss: 8.2400e-04
#
# Epoch 00035: val_loss did not improve from 0.00081
# Epoch 36/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 2.2574e-04 - val_loss: 8.0260e-04
#
# Epoch 00036: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 2.1945e-04 - val_loss: 7.9574e-04
#
# Epoch 00037: val_loss improved from 0.00080 to 0.00080, saving model to best_weights.h5
# Epoch 38/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 2.1646e-04 - val_loss: 8.3563e-04
#
# Epoch 00038: val_loss did not improve from 0.00080
# Epoch 39/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 2.1514e-04 - val_loss: 8.2123e-04
#
# Epoch 00039: val_loss did not improve from 0.00080
# Epoch 40/150
# 1712/1712 [==============================] - 0s 196us/step - loss: 2.1443e-04 - val_loss: 8.1129e-04
#
# Epoch 00040: val_loss did not improve from 0.00080
# Epoch 41/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 2.0870e-04 - val_loss: 8.0282e-04
#
# Epoch 00041: val_loss did not improve from 0.00080
# Epoch 42/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 2.0963e-04 - val_loss: 8.0832e-04
#
# Epoch 00042: val_loss did not improve from 0.00080
# Epoch 43/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 2.0295e-04 - val_loss: 7.8102e-04
#
# Epoch 00043: val_loss improved from 0.00080 to 0.00078, saving model to best_weights.h5
# Epoch 44/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.9718e-04 - val_loss: 7.9142e-04
#
# Epoch 00044: val_loss did not improve from 0.00078
# Epoch 45/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.9776e-04 - val_loss: 7.8103e-04
#
# Epoch 00045: val_loss did not improve from 0.00078
# Epoch 46/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 1.9034e-04 - val_loss: 8.0066e-04
#
# Epoch 00046: val_loss did not improve from 0.00078
# Epoch 47/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.8820e-04 - val_loss: 7.7624e-04
#
# Epoch 00047: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 48/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.9003e-04 - val_loss: 7.8305e-04
#
# Epoch 00048: val_loss did not improve from 0.00078
# Epoch 49/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.9025e-04 - val_loss: 8.0753e-04
#
# Epoch 00049: val_loss did not improve from 0.00078
# Epoch 50/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 1.8745e-04 - val_loss: 7.9496e-04
#
# Epoch 00050: val_loss did not improve from 0.00078
# Epoch 51/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.8074e-04 - val_loss: 7.6706e-04
#
# Epoch 00051: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 52/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.7898e-04 - val_loss: 7.6661e-04
#
# Epoch 00052: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 53/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 1.7828e-04 - val_loss: 7.5684e-04
#
# Epoch 00053: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 54/150
# 1712/1712 [==============================] - 0s 201us/step - loss: 1.7851e-04 - val_loss: 7.7835e-04
#
# Epoch 00054: val_loss did not improve from 0.00076
# Epoch 55/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.7199e-04 - val_loss: 7.6966e-04
#
# Epoch 00055: val_loss did not improve from 0.00076
# Epoch 56/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.7855e-04 - val_loss: 7.5793e-04
#
# Epoch 00056: val_loss did not improve from 0.00076
# Epoch 57/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.7974e-04 - val_loss: 7.8094e-04
#
# Epoch 00057: val_loss did not improve from 0.00076
# Epoch 58/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.7805e-04 - val_loss: 7.8733e-04
#
# Epoch 00058: val_loss did not improve from 0.00076
# Epoch 59/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.6905e-04 - val_loss: 7.8045e-04
#
# Epoch 00059: val_loss did not improve from 0.00076
# Epoch 60/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.7038e-04 - val_loss: 7.7752e-04
#
# Epoch 00060: val_loss did not improve from 0.00076
# Epoch 61/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.6914e-04 - val_loss: 7.7112e-04
#
# Epoch 00061: val_loss did not improve from 0.00076
# Epoch 62/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.6436e-04 - val_loss: 7.8674e-04
#
# Epoch 00062: val_loss did not improve from 0.00076
# Epoch 63/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.5610e-04 - val_loss: 7.6980e-04
#
# Epoch 00063: val_loss did not improve from 0.00076
# Epoch 64/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.5777e-04 - val_loss: 8.0538e-04
#
# Epoch 00064: val_loss did not improve from 0.00076
# Epoch 65/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.5810e-04 - val_loss: 7.9012e-04
#
# Epoch 00065: val_loss did not improve from 0.00076
# Epoch 66/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.5792e-04 - val_loss: 7.6976e-04
#
# Epoch 00066: val_loss did not improve from 0.00076
# Epoch 67/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.5338e-04 - val_loss: 7.6967e-04
#
# Epoch 00067: val_loss did not improve from 0.00076
# Epoch 68/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.5243e-04 - val_loss: 7.8697e-04
#
# Epoch 00068: val_loss did not improve from 0.00076
# Epoch 69/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.4931e-04 - val_loss: 7.7185e-04
#
# Epoch 00069: val_loss did not improve from 0.00076
# Epoch 70/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.4768e-04 - val_loss: 7.7249e-04
#
# Epoch 00070: val_loss did not improve from 0.00076
# Epoch 71/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.5004e-04 - val_loss: 7.6878e-04
#
# Epoch 00071: val_loss did not improve from 0.00076
# Epoch 72/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 1.4594e-04 - val_loss: 7.7100e-04
#
# Epoch 00072: val_loss did not improve from 0.00076
# Epoch 73/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.4700e-04 - val_loss: 8.0430e-04
#
# Epoch 00073: val_loss did not improve from 0.00076
# Epoch 74/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.4225e-04 - val_loss: 7.7533e-04
#
# Epoch 00074: val_loss did not improve from 0.00076
# Epoch 75/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.4448e-04 - val_loss: 7.9219e-04
#
# Epoch 00075: val_loss did not improve from 0.00076
# Epoch 76/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.3963e-04 - val_loss: 8.0203e-04
#
# Epoch 00076: val_loss did not improve from 0.00076
# Epoch 77/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.3839e-04 - val_loss: 8.1708e-04
#
# Epoch 00077: val_loss did not improve from 0.00076
# Epoch 78/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.3831e-04 - val_loss: 7.6206e-04
#
# Epoch 00078: val_loss did not improve from 0.00076
# Epoch 79/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.4160e-04 - val_loss: 7.7781e-04
#
# Epoch 00079: val_loss did not improve from 0.00076
# Epoch 80/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.4012e-04 - val_loss: 7.7061e-04
#
# Epoch 00080: val_loss did not improve from 0.00076
# Epoch 81/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.3640e-04 - val_loss: 7.5609e-04
#
# Epoch 00081: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 82/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.3485e-04 - val_loss: 7.6542e-04
#
# Epoch 00082: val_loss did not improve from 0.00076
# Epoch 83/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.3403e-04 - val_loss: 7.8303e-04
#
# Epoch 00083: val_loss did not improve from 0.00076
# Epoch 84/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.3422e-04 - val_loss: 7.6176e-04
#
# Epoch 00084: val_loss did not improve from 0.00076
# Epoch 85/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.3449e-04 - val_loss: 7.8415e-04
#
# Epoch 00085: val_loss did not improve from 0.00076
# Epoch 86/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.3377e-04 - val_loss: 7.9630e-04
#
# Epoch 00086: val_loss did not improve from 0.00076
# Epoch 87/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.2908e-04 - val_loss: 7.7119e-04
#
# Epoch 00087: val_loss did not improve from 0.00076
# Epoch 88/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.2638e-04 - val_loss: 7.6868e-04
#
# Epoch 00088: val_loss did not improve from 0.00076
# Epoch 89/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.2719e-04 - val_loss: 7.5481e-04
#
# Epoch 00089: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 90/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.2890e-04 - val_loss: 7.5814e-04
#
# Epoch 00090: val_loss did not improve from 0.00075
# Epoch 91/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.2531e-04 - val_loss: 7.5976e-04
#
# Epoch 00091: val_loss did not improve from 0.00075
# Epoch 92/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.2312e-04 - val_loss: 7.5817e-04
#
# Epoch 00092: val_loss did not improve from 0.00075
# Epoch 93/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.2208e-04 - val_loss: 7.6960e-04
#
# Epoch 00093: val_loss did not improve from 0.00075
# Epoch 94/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.1926e-04 - val_loss: 7.4425e-04
#
# Epoch 00094: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 95/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.2192e-04 - val_loss: 7.6724e-04
#
# Epoch 00095: val_loss did not improve from 0.00074
# Epoch 96/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 1.2497e-04 - val_loss: 7.8740e-04
#
# Epoch 00096: val_loss did not improve from 0.00074
# Epoch 97/150
# 1712/1712 [==============================] - 0s 201us/step - loss: 1.2478e-04 - val_loss: 7.5337e-04
#
# Epoch 00097: val_loss did not improve from 0.00074
# Epoch 98/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.1946e-04 - val_loss: 7.7337e-04
#
# Epoch 00098: val_loss did not improve from 0.00074
# Epoch 99/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.2076e-04 - val_loss: 7.4816e-04
#
# Epoch 00099: val_loss did not improve from 0.00074
# Epoch 100/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.1645e-04 - val_loss: 7.6967e-04
#
# Epoch 00100: val_loss did not improve from 0.00074
# Epoch 101/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.1396e-04 - val_loss: 7.5091e-04
#
# Epoch 00101: val_loss did not improve from 0.00074
# Epoch 102/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.1772e-04 - val_loss: 7.5531e-04
#
# Epoch 00102: val_loss did not improve from 0.00074
# Epoch 103/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.1790e-04 - val_loss: 7.7134e-04
#
# Epoch 00103: val_loss did not improve from 0.00074
# Epoch 104/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.1489e-04 - val_loss: 7.9953e-04
#
# Epoch 00104: val_loss did not improve from 0.00074
# Epoch 105/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 1.1527e-04 - val_loss: 7.8156e-04
#
# Epoch 00105: val_loss did not improve from 0.00074
# Epoch 106/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.1233e-04 - val_loss: 7.6869e-04
#
# Epoch 00106: val_loss did not improve from 0.00074
# Epoch 107/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 1.1435e-04 - val_loss: 7.4456e-04
#
# Epoch 00107: val_loss did not improve from 0.00074
# Epoch 108/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.1488e-04 - val_loss: 7.9747e-04
#
# Epoch 00108: val_loss did not improve from 0.00074
# Epoch 109/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.1243e-04 - val_loss: 7.7305e-04
#
# Epoch 00109: val_loss did not improve from 0.00074
# Epoch 110/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.1195e-04 - val_loss: 7.8726e-04
#
# Epoch 00110: val_loss did not improve from 0.00074
# Epoch 111/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.1090e-04 - val_loss: 8.0769e-04
#
# Epoch 00111: val_loss did not improve from 0.00074
# Epoch 112/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.1246e-04 - val_loss: 7.6043e-04
#
# Epoch 00112: val_loss did not improve from 0.00074
# Epoch 113/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.0954e-04 - val_loss: 7.4226e-04
#
# Epoch 00113: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 114/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.1362e-04 - val_loss: 7.7934e-04
#
# Epoch 00114: val_loss did not improve from 0.00074
# Epoch 115/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 1.0907e-04 - val_loss: 7.6062e-04
#
# Epoch 00115: val_loss did not improve from 0.00074
# Epoch 116/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.0770e-04 - val_loss: 7.9886e-04
#
# Epoch 00116: val_loss did not improve from 0.00074
# Epoch 117/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.0382e-04 - val_loss: 7.8122e-04
#
# Epoch 00117: val_loss did not improve from 0.00074
# Epoch 118/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.0668e-04 - val_loss: 7.9139e-04
#
# Epoch 00118: val_loss did not improve from 0.00074
# Epoch 119/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.0376e-04 - val_loss: 7.5112e-04
#
# Epoch 00119: val_loss did not improve from 0.00074
# Epoch 120/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.0482e-04 - val_loss: 7.5721e-04
#
# Epoch 00120: val_loss did not improve from 0.00074
# Epoch 121/150
# 1712/1712 [==============================] - 0s 201us/step - loss: 1.0387e-04 - val_loss: 7.5572e-04
#
# Epoch 00121: val_loss did not improve from 0.00074
# Epoch 122/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.0421e-04 - val_loss: 7.5830e-04
#
# Epoch 00122: val_loss did not improve from 0.00074
# Epoch 123/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.0338e-04 - val_loss: 7.7333e-04
#
# Epoch 00123: val_loss did not improve from 0.00074
# Epoch 124/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.0270e-04 - val_loss: 7.7543e-04
#
# Epoch 00124: val_loss did not improve from 0.00074
# Epoch 125/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.0326e-04 - val_loss: 7.5713e-04
#
# Epoch 00125: val_loss did not improve from 0.00074
# Epoch 126/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.0223e-04 - val_loss: 7.5805e-04
#
# Epoch 00126: val_loss did not improve from 0.00074
# Epoch 127/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 9.7785e-05 - val_loss: 7.5296e-04
#
# Epoch 00127: val_loss did not improve from 0.00074
# Epoch 128/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 9.7930e-05 - val_loss: 7.4688e-04
#
# Epoch 00128: val_loss did not improve from 0.00074
# Epoch 129/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 9.7838e-05 - val_loss: 7.4925e-04
#
# Epoch 00129: val_loss did not improve from 0.00074
# Epoch 130/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 9.9813e-05 - val_loss: 7.5220e-04
#
# Epoch 00130: val_loss did not improve from 0.00074
# Epoch 131/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 9.8299e-05 - val_loss: 7.9785e-04
#
# Epoch 00131: val_loss did not improve from 0.00074
# Epoch 132/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 9.8576e-05 - val_loss: 7.6925e-04
#
# Epoch 00132: val_loss did not improve from 0.00074
# Epoch 133/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 9.7926e-05 - val_loss: 7.5063e-04
#
# Epoch 00133: val_loss did not improve from 0.00074
# Epoch 134/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 9.5554e-05 - val_loss: 7.8098e-04
#
# Epoch 00134: val_loss did not improve from 0.00074
# Epoch 135/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 9.8152e-05 - val_loss: 7.8177e-04
#
# Epoch 00135: val_loss did not improve from 0.00074
# Epoch 136/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 9.5185e-05 - val_loss: 7.9708e-04
#
# Epoch 00136: val_loss did not improve from 0.00074
# Epoch 137/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 9.5639e-05 - val_loss: 7.6759e-04
#
# Epoch 00137: val_loss did not improve from 0.00074
# Epoch 138/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 9.3702e-05 - val_loss: 7.9634e-04
#
# Epoch 00138: val_loss did not improve from 0.00074
# Epoch 139/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 9.5487e-05 - val_loss: 7.6837e-04
#
# Epoch 00139: val_loss did not improve from 0.00074
# Epoch 140/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 9.1605e-05 - val_loss: 7.5597e-04
#
# Epoch 00140: val_loss did not improve from 0.00074
# Epoch 141/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 9.2581e-05 - val_loss: 7.5731e-04
#
# Epoch 00141: val_loss did not improve from 0.00074
# Epoch 142/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 9.0429e-05 - val_loss: 7.5714e-04
#
# Epoch 00142: val_loss did not improve from 0.00074
# Epoch 143/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 8.9782e-05 - val_loss: 7.4064e-04
#
# Epoch 00143: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 144/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 9.0141e-05 - val_loss: 7.9044e-04
#
# Epoch 00144: val_loss did not improve from 0.00074
# Epoch 145/150
# 1712/1712 [==============================] - 0s 201us/step - loss: 9.8294e-05 - val_loss: 7.6759e-04
#
# Epoch 00145: val_loss did not improve from 0.00074
# Epoch 146/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 8.9753e-05 - val_loss: 7.6937e-04
#
# Epoch 00146: val_loss did not improve from 0.00074
# Epoch 147/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 8.9741e-05 - val_loss: 7.5985e-04
#
# Epoch 00147: val_loss did not improve from 0.00074
# Epoch 148/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 8.9818e-05 - val_loss: 7.7639e-04
#
# Epoch 00148: val_loss did not improve from 0.00074
# Epoch 149/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 9.2687e-05 - val_loss: 7.5251e-04
#
# Epoch 00149: val_loss did not improve from 0.00074
# Epoch 150/150
# 1712/1712 [==============================] - 0s 201us/step - loss: 9.4351e-05 - val_loss: 7.4289e-04
#
# Epoch 00150: val_loss did not improve from 0.00074

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
from imgaug import augmenters as iaa

# %%
imgs_train.shape
# Out:
# (2140, 96, 96)

# %%
fig = plt.figure(figsize= (15,15))

for i in range(5):
    ax = fig.add_subplot(1, 5, i+1)
    plot_keypoints(imgs_train[i], points_train[i])

# %%
fig = plt.figure(figsize= (15,15))
flipper = iaa.Fliplr()
img_train_flip = flipper.augment_images(imgs_train)
points_train_flip = np.array([[-p if (i % 2) == 0 else p for i, p in enumerate(image)] for image in points_train])
for i in range(5):
    ax = fig.add_subplot(1, 5, i+1)
    plot_keypoints(img_train_flip[i], points_train_flip[i])

# %%
imgs_train_flip = flipper.augment_images(imgs_train)
points_train_flip = np.array([[-p if (i % 2) == 0 else p for i, p in enumerate(image)] for image in points_train])

# %%
points_train_flip_temp = points_train_flip.copy()
points_train_flip[:, 0:2] = points_train_flip_temp[:, 2:4]
points_train_flip[:, 2:4] = points_train_flip_temp[:, 0:2]
points_train_flip[:, 4:8] = points_train_flip_temp[:, 8:12]
points_train_flip[:, 8:12] = points_train_flip_temp[:, 4:8]
points_train_flip[:, 12:16] = points_train_flip_temp[:, 16:20]
points_train_flip[:, 16:20] = points_train_flip_temp[:, 12:16]
points_train_flip[:, 22:24] = points_train_flip_temp[:, 24:26]
points_train_flip[:, 24:26] = points_train_flip_temp[:, 22:24]

# %%
imgs_train_full = np.vstack([imgs_train, imgs_train_flip])
points_train_full = np.vstack([points_train, points_train_flip])

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_aug.h5', verbose=1, save_best_only=True)
hist_aug = History()

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# training the model
hist_model_with_augment = model_with_augment.fit(imgs_train_full.reshape(-1, 96, 96, 1), 
                                                 points_train_full, 
                                                 validation_split= 0.2, 
                                                 batch_size=64, callbacks=[checkpoint_aug, hist_aug],
                                                 shuffle=True, epochs=150, verbose=1)
# save the model weights
model_with_augment.save_weights('weights_aug.h5')
# save the model
model_with_augment.save('model_aug.h5')
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 0.0038 - val_loss: 0.0016
#
# Epoch 00001: val_loss improved from inf to 0.00159, saving model to best_weights_aug.h5
# Epoch 2/150
# 3424/3424 [==============================] - 1s 223us/step - loss: 0.0013 - val_loss: 0.0016
#
# Epoch 00002: val_loss improved from 0.00159 to 0.00159, saving model to best_weights_aug.h5
# Epoch 3/150
# 3424/3424 [==============================] - 1s 225us/step - loss: 0.0011 - val_loss: 0.0015
#
# Epoch 00003: val_loss improved from 0.00159 to 0.00146, saving model to best_weights_aug.h5
# Epoch 4/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 9.3956e-04 - val_loss: 0.0012
#
# Epoch 00004: val_loss improved from 0.00146 to 0.00119, saving model to best_weights_aug.h5
# Epoch 5/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 7.4442e-04 - val_loss: 9.0005e-04
#
# Epoch 00005: val_loss improved from 0.00119 to 0.00090, saving model to best_weights_aug.h5
# Epoch 6/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 6.0465e-04 - val_loss: 7.8199e-04
#
# Epoch 00006: val_loss improved from 0.00090 to 0.00078, saving model to best_weights_aug.h5
# Epoch 7/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 5.3365e-04 - val_loss: 6.7632e-04
#
# Epoch 00007: val_loss improved from 0.00078 to 0.00068, saving model to best_weights_aug.h5
# Epoch 8/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 4.8359e-04 - val_loss: 6.3085e-04
#
# Epoch 00008: val_loss improved from 0.00068 to 0.00063, saving model to best_weights_aug.h5
# Epoch 9/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 4.4188e-04 - val_loss: 5.8850e-04
#
# Epoch 00009: val_loss improved from 0.00063 to 0.00059, saving model to best_weights_aug.h5
# Epoch 10/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 4.0757e-04 - val_loss: 5.6418e-04
#
# Epoch 00010: val_loss improved from 0.00059 to 0.00056, saving model to best_weights_aug.h5
# Epoch 11/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 3.8692e-04 - val_loss: 5.5836e-04
#
# Epoch 00011: val_loss improved from 0.00056 to 0.00056, saving model to best_weights_aug.h5
# Epoch 12/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 3.6386e-04 - val_loss: 5.5503e-04
#
# Epoch 00012: val_loss improved from 0.00056 to 0.00056, saving model to best_weights_aug.h5
# Epoch 13/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 3.3849e-04 - val_loss: 5.1197e-04
#
# Epoch 00013: val_loss improved from 0.00056 to 0.00051, saving model to best_weights_aug.h5
# Epoch 14/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 3.1992e-04 - val_loss: 4.7930e-04
#
# Epoch 00014: val_loss improved from 0.00051 to 0.00048, saving model to best_weights_aug.h5
# Epoch 15/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 3.0265e-04 - val_loss: 4.7807e-04
#
# Epoch 00015: val_loss improved from 0.00048 to 0.00048, saving model to best_weights_aug.h5
# Epoch 16/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 2.8987e-04 - val_loss: 4.5392e-04
#
# Epoch 00016: val_loss improved from 0.00048 to 0.00045, saving model to best_weights_aug.h5
# Epoch 17/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 2.8665e-04 - val_loss: 4.6416e-04
#
# Epoch 00017: val_loss did not improve from 0.00045
# Epoch 18/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 2.7650e-04 - val_loss: 4.3288e-04
#
# Epoch 00018: val_loss improved from 0.00045 to 0.00043, saving model to best_weights_aug.h5
# Epoch 19/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 2.6480e-04 - val_loss: 4.3823e-04
#
# Epoch 00019: val_loss did not improve from 0.00043
# Epoch 20/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 2.5964e-04 - val_loss: 4.2313e-04
#
# Epoch 00020: val_loss improved from 0.00043 to 0.00042, saving model to best_weights_aug.h5
# Epoch 21/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 2.5738e-04 - val_loss: 4.5178e-04
#
# Epoch 00021: val_loss did not improve from 0.00042
# Epoch 22/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 2.4285e-04 - val_loss: 4.3073e-04
#
# Epoch 00022: val_loss did not improve from 0.00042
# Epoch 23/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 2.3976e-04 - val_loss: 4.1697e-04
#
# Epoch 00023: val_loss improved from 0.00042 to 0.00042, saving model to best_weights_aug.h5
# Epoch 24/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 2.3326e-04 - val_loss: 4.1744e-04
#
# Epoch 00024: val_loss did not improve from 0.00042
# Epoch 25/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 2.2039e-04 - val_loss: 4.2211e-04
#
# Epoch 00025: val_loss did not improve from 0.00042
# Epoch 26/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 2.2512e-04 - val_loss: 4.3810e-04
#
# Epoch 00026: val_loss did not improve from 0.00042
# Epoch 27/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 2.1826e-04 - val_loss: 4.1793e-04
#
# Epoch 00027: val_loss did not improve from 0.00042
# Epoch 28/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 2.1300e-04 - val_loss: 4.1443e-04
#
# Epoch 00028: val_loss improved from 0.00042 to 0.00041, saving model to best_weights_aug.h5
# Epoch 29/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 2.0315e-04 - val_loss: 3.9934e-04
#
# Epoch 00029: val_loss improved from 0.00041 to 0.00040, saving model to best_weights_aug.h5
# Epoch 30/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 2.0098e-04 - val_loss: 4.4375e-04
#
# Epoch 00030: val_loss did not improve from 0.00040
# Epoch 31/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 2.0087e-04 - val_loss: 4.0710e-04
#
# Epoch 00031: val_loss did not improve from 0.00040
# Epoch 32/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 1.9598e-04 - val_loss: 3.9553e-04
#
# Epoch 00032: val_loss improved from 0.00040 to 0.00040, saving model to best_weights_aug.h5
# Epoch 33/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 1.9320e-04 - val_loss: 3.9681e-04
#
# Epoch 00033: val_loss did not improve from 0.00040
# Epoch 34/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 1.9182e-04 - val_loss: 3.9391e-04
#
# Epoch 00034: val_loss improved from 0.00040 to 0.00039, saving model to best_weights_aug.h5
# Epoch 35/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 1.8548e-04 - val_loss: 4.0592e-04
#
# Epoch 00035: val_loss did not improve from 0.00039
# Epoch 36/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 1.8261e-04 - val_loss: 4.1261e-04
#
# Epoch 00036: val_loss did not improve from 0.00039
# Epoch 37/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 1.7925e-04 - val_loss: 3.9305e-04
#
# Epoch 00037: val_loss improved from 0.00039 to 0.00039, saving model to best_weights_aug.h5
# Epoch 38/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 1.7487e-04 - val_loss: 3.9124e-04
#
# Epoch 00038: val_loss improved from 0.00039 to 0.00039, saving model to best_weights_aug.h5
# Epoch 39/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 1.7182e-04 - val_loss: 4.0542e-04
#
# Epoch 00039: val_loss did not improve from 0.00039
# Epoch 40/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 1.7004e-04 - val_loss: 4.1115e-04
#
# Epoch 00040: val_loss did not improve from 0.00039
# Epoch 41/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 1.6999e-04 - val_loss: 3.7476e-04
#
# Epoch 00041: val_loss improved from 0.00039 to 0.00037, saving model to best_weights_aug.h5
# Epoch 42/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 1.6915e-04 - val_loss: 3.9089e-04
#
# Epoch 00042: val_loss did not improve from 0.00037
# Epoch 43/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 1.6186e-04 - val_loss: 4.0783e-04
#
# Epoch 00043: val_loss did not improve from 0.00037
# Epoch 44/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 1.5999e-04 - val_loss: 4.1216e-04
#
# Epoch 00044: val_loss did not improve from 0.00037
# Epoch 45/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 1.5843e-04 - val_loss: 4.2895e-04
#
# Epoch 00045: val_loss did not improve from 0.00037
# Epoch 46/150
# 3424/3424 [==============================] - 1s 257us/step - loss: 1.5677e-04 - val_loss: 3.9733e-04
#
# Epoch 00046: val_loss did not improve from 0.00037
# Epoch 47/150
# 3424/3424 [==============================] - 1s 218us/step - loss: 1.5492e-04 - val_loss: 4.0163e-04
#
# Epoch 00047: val_loss did not improve from 0.00037
# Epoch 48/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.5757e-04 - val_loss: 4.0037e-04
#
# Epoch 00048: val_loss did not improve from 0.00037
# Epoch 49/150
# 3424/3424 [==============================] - 1s 219us/step - loss: 1.5273e-04 - val_loss: 3.7398e-04
#
# Epoch 00049: val_loss improved from 0.00037 to 0.00037, saving model to best_weights_aug.h5
# Epoch 50/150
# 3424/3424 [==============================] - 1s 227us/step - loss: 1.4877e-04 - val_loss: 3.8350e-04
#
# Epoch 00050: val_loss did not improve from 0.00037
# Epoch 51/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 1.4625e-04 - val_loss: 3.7212e-04
#
# Epoch 00051: val_loss improved from 0.00037 to 0.00037, saving model to best_weights_aug.h5
# Epoch 52/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 1.4432e-04 - val_loss: 3.9786e-04
#
# Epoch 00052: val_loss did not improve from 0.00037
# Epoch 53/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 1.4394e-04 - val_loss: 3.6963e-04
#
# Epoch 00053: val_loss improved from 0.00037 to 0.00037, saving model to best_weights_aug.h5
# Epoch 54/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 1.3962e-04 - val_loss: 3.8987e-04
#
# Epoch 00054: val_loss did not improve from 0.00037
# Epoch 55/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 1.3986e-04 - val_loss: 3.7512e-04
#
# Epoch 00055: val_loss did not improve from 0.00037
# Epoch 56/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 1.3733e-04 - val_loss: 3.8290e-04
#
# Epoch 00056: val_loss did not improve from 0.00037
# Epoch 57/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 1.3541e-04 - val_loss: 3.7184e-04
#
# Epoch 00057: val_loss did not improve from 0.00037
# Epoch 58/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 1.3617e-04 - val_loss: 3.7890e-04
#
# Epoch 00058: val_loss did not improve from 0.00037
# Epoch 59/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 1.3377e-04 - val_loss: 3.7047e-04
#
# Epoch 00059: val_loss did not improve from 0.00037
# Epoch 60/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 1.3079e-04 - val_loss: 3.8406e-04
#
# Epoch 00060: val_loss did not improve from 0.00037
# Epoch 61/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 1.3056e-04 - val_loss: 3.8981e-04
#
# Epoch 00061: val_loss did not improve from 0.00037
# Epoch 62/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 1.2887e-04 - val_loss: 3.7814e-04
#
# Epoch 00062: val_loss did not improve from 0.00037
# Epoch 63/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 1.2560e-04 - val_loss: 3.8777e-04
#
# Epoch 00063: val_loss did not improve from 0.00037
# Epoch 64/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 1.2522e-04 - val_loss: 3.8250e-04
#
# Epoch 00064: val_loss did not improve from 0.00037
# Epoch 65/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 1.2752e-04 - val_loss: 3.7954e-04
#
# Epoch 00065: val_loss did not improve from 0.00037
# Epoch 66/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 1.3013e-04 - val_loss: 4.0753e-04
#
# Epoch 00066: val_loss did not improve from 0.00037
# Epoch 67/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 1.2404e-04 - val_loss: 3.7866e-04
#
# Epoch 00067: val_loss did not improve from 0.00037
# Epoch 68/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 1.2062e-04 - val_loss: 3.7823e-04
#
# Epoch 00068: val_loss did not improve from 0.00037
# Epoch 69/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 1.1957e-04 - val_loss: 3.8048e-04
#
# Epoch 00069: val_loss did not improve from 0.00037
# Epoch 70/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 1.1728e-04 - val_loss: 3.7260e-04
#
# Epoch 00070: val_loss did not improve from 0.00037
# Epoch 71/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 1.1812e-04 - val_loss: 3.6433e-04
#
# Epoch 00071: val_loss improved from 0.00037 to 0.00036, saving model to best_weights_aug.h5
# Epoch 72/150
# 3424/3424 [==============================] - 1s 226us/step - loss: 1.1783e-04 - val_loss: 3.8945e-04
#
# Epoch 00072: val_loss did not improve from 0.00036
# Epoch 73/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 1.1563e-04 - val_loss: 3.7330e-04
#
# Epoch 00073: val_loss did not improve from 0.00036
# Epoch 74/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 1.1947e-04 - val_loss: 3.6970e-04
#
# Epoch 00074: val_loss did not improve from 0.00036
# Epoch 75/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 1.1630e-04 - val_loss: 3.9004e-04
#
# Epoch 00075: val_loss did not improve from 0.00036
# Epoch 76/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 1.1290e-04 - val_loss: 3.7523e-04
#
# Epoch 00076: val_loss did not improve from 0.00036
# Epoch 77/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 1.1081e-04 - val_loss: 3.8024e-04
#
# Epoch 00077: val_loss did not improve from 0.00036
# Epoch 78/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 1.1206e-04 - val_loss: 3.9043e-04
#
# Epoch 00078: val_loss did not improve from 0.00036
# Epoch 79/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 1.1233e-04 - val_loss: 3.6110e-04
#
# Epoch 00079: val_loss improved from 0.00036 to 0.00036, saving model to best_weights_aug.h5
# Epoch 80/150
# 3424/3424 [==============================] - 1s 223us/step - loss: 1.0827e-04 - val_loss: 3.7499e-04
#
# Epoch 00080: val_loss did not improve from 0.00036
# Epoch 81/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 1.0918e-04 - val_loss: 3.7977e-04
#
# Epoch 00081: val_loss did not improve from 0.00036
# Epoch 82/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 1.0915e-04 - val_loss: 3.7088e-04
#
# Epoch 00082: val_loss did not improve from 0.00036
# Epoch 83/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 1.0779e-04 - val_loss: 3.7354e-04
#
# Epoch 00083: val_loss did not improve from 0.00036
# Epoch 84/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 1.0593e-04 - val_loss: 3.8271e-04
#
# Epoch 00084: val_loss did not improve from 0.00036
# Epoch 85/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 1.0587e-04 - val_loss: 3.6368e-04
#
# Epoch 00085: val_loss did not improve from 0.00036
# Epoch 86/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 1.0508e-04 - val_loss: 3.6863e-04
#
# Epoch 00086: val_loss did not improve from 0.00036
# Epoch 87/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 1.0441e-04 - val_loss: 3.7949e-04
#
# Epoch 00087: val_loss did not improve from 0.00036
# Epoch 88/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 1.0480e-04 - val_loss: 3.7668e-04
#
# Epoch 00088: val_loss did not improve from 0.00036
# Epoch 89/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 1.0256e-04 - val_loss: 3.7138e-04
#
# Epoch 00089: val_loss did not improve from 0.00036
# Epoch 90/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 1.0319e-04 - val_loss: 3.8852e-04
#
# Epoch 00090: val_loss did not improve from 0.00036
# Epoch 91/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 1.0277e-04 - val_loss: 3.7647e-04
#
# Epoch 00091: val_loss did not improve from 0.00036
# Epoch 92/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 1.0252e-04 - val_loss: 3.7191e-04
#
# Epoch 00092: val_loss did not improve from 0.00036
# Epoch 93/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 1.0090e-04 - val_loss: 3.7481e-04
#
# Epoch 00093: val_loss did not improve from 0.00036
# Epoch 94/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 9.9232e-05 - val_loss: 3.8658e-04
#
# Epoch 00094: val_loss did not improve from 0.00036
# Epoch 95/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 1.0015e-04 - val_loss: 3.8512e-04
#
# Epoch 00095: val_loss did not improve from 0.00036
# Epoch 96/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 9.9599e-05 - val_loss: 3.6709e-04
#
# Epoch 00096: val_loss did not improve from 0.00036
# Epoch 97/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 9.8970e-05 - val_loss: 3.7370e-04
#
# Epoch 00097: val_loss did not improve from 0.00036
# Epoch 98/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 9.7972e-05 - val_loss: 3.8895e-04
#
# Epoch 00098: val_loss did not improve from 0.00036
# Epoch 99/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 9.9276e-05 - val_loss: 3.8750e-04
#
# Epoch 00099: val_loss did not improve from 0.00036
# Epoch 100/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 9.8164e-05 - val_loss: 3.7878e-04
#
# Epoch 00100: val_loss did not improve from 0.00036
# Epoch 101/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 9.8584e-05 - val_loss: 3.7010e-04
#
# Epoch 00101: val_loss did not improve from 0.00036
# Epoch 102/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 9.9362e-05 - val_loss: 3.6927e-04
#
# Epoch 00102: val_loss did not improve from 0.00036
# Epoch 103/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 9.8361e-05 - val_loss: 3.7355e-04
#
# Epoch 00103: val_loss did not improve from 0.00036
# Epoch 104/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 9.9090e-05 - val_loss: 3.7565e-04
#
# Epoch 00104: val_loss did not improve from 0.00036
# Epoch 105/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 9.6087e-05 - val_loss: 3.7220e-04
#
# Epoch 00105: val_loss did not improve from 0.00036
# Epoch 106/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 9.5539e-05 - val_loss: 3.8544e-04
#
# Epoch 00106: val_loss did not improve from 0.00036
# Epoch 107/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 9.2808e-05 - val_loss: 3.7904e-04
#
# Epoch 00107: val_loss did not improve from 0.00036
# Epoch 108/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 9.2111e-05 - val_loss: 3.8049e-04
#
# Epoch 00108: val_loss did not improve from 0.00036
# Epoch 109/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 9.3871e-05 - val_loss: 3.8659e-04
#
# Epoch 00109: val_loss did not improve from 0.00036
# Epoch 110/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 9.2786e-05 - val_loss: 3.9398e-04
#
# Epoch 00110: val_loss did not improve from 0.00036
# Epoch 111/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 9.4324e-05 - val_loss: 3.8099e-04
#
# Epoch 00111: val_loss did not improve from 0.00036
# Epoch 112/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 9.2362e-05 - val_loss: 3.9399e-04
#
# Epoch 00112: val_loss did not improve from 0.00036
# Epoch 113/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 9.2505e-05 - val_loss: 3.7959e-04
#
# Epoch 00113: val_loss did not improve from 0.00036
# Epoch 114/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 9.1795e-05 - val_loss: 3.8107e-04
#
# Epoch 00114: val_loss did not improve from 0.00036
# Epoch 115/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 9.0978e-05 - val_loss: 3.8450e-04
#
# Epoch 00115: val_loss did not improve from 0.00036
# Epoch 116/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 9.0231e-05 - val_loss: 3.7207e-04
#
# Epoch 00116: val_loss did not improve from 0.00036
# Epoch 117/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 9.3253e-05 - val_loss: 3.7108e-04
#
# Epoch 00117: val_loss did not improve from 0.00036
# Epoch 118/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 9.1627e-05 - val_loss: 3.7321e-04
#
# Epoch 00118: val_loss did not improve from 0.00036
# Epoch 119/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 9.0632e-05 - val_loss: 3.8930e-04
#
# Epoch 00119: val_loss did not improve from 0.00036
# Epoch 120/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 9.0527e-05 - val_loss: 3.8122e-04
#
# Epoch 00120: val_loss did not improve from 0.00036
# Epoch 121/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 9.0016e-05 - val_loss: 3.7782e-04
#
# Epoch 00121: val_loss did not improve from 0.00036
# Epoch 122/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 8.8769e-05 - val_loss: 3.7544e-04
#
# Epoch 00122: val_loss did not improve from 0.00036
# Epoch 123/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 8.8753e-05 - val_loss: 3.8270e-04
#
# Epoch 00123: val_loss did not improve from 0.00036
# Epoch 124/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 8.8411e-05 - val_loss: 3.8223e-04
#
# Epoch 00124: val_loss did not improve from 0.00036
# Epoch 125/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 9.0457e-05 - val_loss: 3.8322e-04
#
# Epoch 00125: val_loss did not improve from 0.00036
# Epoch 126/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 8.6720e-05 - val_loss: 3.7088e-04
#
# Epoch 00126: val_loss did not improve from 0.00036
# Epoch 127/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 8.9806e-05 - val_loss: 3.7231e-04
#
# Epoch 00127: val_loss did not improve from 0.00036
# Epoch 128/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 8.6623e-05 - val_loss: 3.7893e-04
#
# Epoch 00128: val_loss did not improve from 0.00036
# Epoch 129/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 8.5078e-05 - val_loss: 3.8394e-04
#
# Epoch 00129: val_loss did not improve from 0.00036
# Epoch 130/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 8.7055e-05 - val_loss: 3.7920e-04
#
# Epoch 00130: val_loss did not improve from 0.00036
# Epoch 131/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 8.6437e-05 - val_loss: 3.7600e-04
#
# Epoch 00131: val_loss did not improve from 0.00036
# Epoch 132/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 8.9019e-05 - val_loss: 3.7721e-04
#
# Epoch 00132: val_loss did not improve from 0.00036
# Epoch 133/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 8.9066e-05 - val_loss: 3.9164e-04
#
# Epoch 00133: val_loss did not improve from 0.00036
# Epoch 134/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 8.7491e-05 - val_loss: 3.7665e-04
#
# Epoch 00134: val_loss did not improve from 0.00036
# Epoch 135/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 8.6924e-05 - val_loss: 3.8940e-04
#
# Epoch 00135: val_loss did not improve from 0.00036
# Epoch 136/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 8.5584e-05 - val_loss: 3.8636e-04
#
# Epoch 00136: val_loss did not improve from 0.00036
# Epoch 137/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 8.3923e-05 - val_loss: 3.7749e-04
#
# Epoch 00137: val_loss did not improve from 0.00036
# Epoch 138/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 8.6340e-05 - val_loss: 3.9816e-04
#
# Epoch 00138: val_loss did not improve from 0.00036
# Epoch 139/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 8.7829e-05 - val_loss: 3.9032e-04
#
# Epoch 00139: val_loss did not improve from 0.00036
# Epoch 140/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 8.5445e-05 - val_loss: 3.8758e-04
#
# Epoch 00140: val_loss did not improve from 0.00036
# Epoch 141/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 8.2911e-05 - val_loss: 3.8740e-04
#
# Epoch 00141: val_loss did not improve from 0.00036
# Epoch 142/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 8.5157e-05 - val_loss: 3.8817e-04
#
# Epoch 00142: val_loss did not improve from 0.00036
# Epoch 143/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 8.3666e-05 - val_loss: 3.7924e-04
#
# Epoch 00143: val_loss did not improve from 0.00036
# Epoch 144/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 8.3291e-05 - val_loss: 3.9119e-04
#
# Epoch 00144: val_loss did not improve from 0.00036
# Epoch 145/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 8.3707e-05 - val_loss: 3.8194e-04
#
# Epoch 00145: val_loss did not improve from 0.00036
# Epoch 146/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 8.2615e-05 - val_loss: 3.8096e-04
#
# Epoch 00146: val_loss did not improve from 0.00036
# Epoch 147/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 8.4983e-05 - val_loss: 3.8041e-04
#
# Epoch 00147: val_loss did not improve from 0.00036
# Epoch 148/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 8.2187e-05 - val_loss: 3.8012e-04
#
# Epoch 00148: val_loss did not improve from 0.00036
# Epoch 149/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 8.2073e-05 - val_loss: 3.8144e-04
#
# Epoch 00149: val_loss did not improve from 0.00036
# Epoch 150/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 8.2267e-05 - val_loss: 3.8546e-04
#
# Epoch 00150: val_loss did not improve from 0.00036

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.plot(hist_model_with_augment.history['loss'], color='g', label='Training Loss with augment')
plt.plot(hist_model_with_augment.history['val_loss'], color='k', label='Validation Loss with augment')
plt.legend(loc='upper right')
