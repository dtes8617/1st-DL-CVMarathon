# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)

import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4
# Out:
# 1.13.1
# E:\GitHub\1st-DL-CVMarathon\Homework\cupoy_cv_part4

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From D:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From D:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 16s 9ms/step - loss: 0.0080 - val_loss: 0.0024
#
# Epoch 00001: val_loss improved from inf to 0.00236, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 0.0020 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00236 to 0.00186, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 0.0015 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00186 to 0.00182, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00182
# Epoch 5/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00005: val_loss did not improve from 0.00182
# Epoch 6/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00182 to 0.00181, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 9.4291e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00181 to 0.00161, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 7.9625e-04 - val_loss: 0.0014
#
# Epoch 00008: val_loss improved from 0.00161 to 0.00143, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 6.9890e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00143 to 0.00130, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 6.2441e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00130 to 0.00116, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 5.6353e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00116 to 0.00114, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 5.1826e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00114 to 0.00107, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 4.8940e-04 - val_loss: 9.8422e-04
#
# Epoch 00013: val_loss improved from 0.00107 to 0.00098, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 4.5633e-04 - val_loss: 9.9209e-04
#
# Epoch 00014: val_loss did not improve from 0.00098
# Epoch 15/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 4.2991e-04 - val_loss: 0.0010
#
# Epoch 00015: val_loss did not improve from 0.00098
# Epoch 16/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 4.1685e-04 - val_loss: 9.4883e-04
#
# Epoch 00016: val_loss improved from 0.00098 to 0.00095, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 3.9185e-04 - val_loss: 9.1942e-04
#
# Epoch 00017: val_loss improved from 0.00095 to 0.00092, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 3.5641e-04 - val_loss: 8.5783e-04
#
# Epoch 00018: val_loss improved from 0.00092 to 0.00086, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 3.4900e-04 - val_loss: 8.4083e-04
#
# Epoch 00019: val_loss improved from 0.00086 to 0.00084, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 3.3167e-04 - val_loss: 8.2475e-04
#
# Epoch 00020: val_loss improved from 0.00084 to 0.00082, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 3.3989e-04 - val_loss: 8.3981e-04
#
# Epoch 00021: val_loss did not improve from 0.00082
# Epoch 22/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 3.2190e-04 - val_loss: 8.2099e-04
#
# Epoch 00022: val_loss improved from 0.00082 to 0.00082, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 3.1136e-04 - val_loss: 8.1794e-04
#
# Epoch 00023: val_loss improved from 0.00082 to 0.00082, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 2.9462e-04 - val_loss: 7.8449e-04
#
# Epoch 00024: val_loss improved from 0.00082 to 0.00078, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 2.8230e-04 - val_loss: 7.6788e-04
#
# Epoch 00025: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 2.8299e-04 - val_loss: 7.6118e-04
#
# Epoch 00026: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 2.7191e-04 - val_loss: 7.6122e-04
#
# Epoch 00027: val_loss did not improve from 0.00076
# Epoch 28/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 2.6816e-04 - val_loss: 7.5279e-04
#
# Epoch 00028: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 29/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 2.6076e-04 - val_loss: 7.7601e-04
#
# Epoch 00029: val_loss did not improve from 0.00075
# Epoch 30/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 2.5335e-04 - val_loss: 7.5831e-04
#
# Epoch 00030: val_loss did not improve from 0.00075
# Epoch 31/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 2.4824e-04 - val_loss: 7.6059e-04
#
# Epoch 00031: val_loss did not improve from 0.00075
# Epoch 32/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 2.4797e-04 - val_loss: 7.3491e-04
#
# Epoch 00032: val_loss improved from 0.00075 to 0.00073, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 2.4517e-04 - val_loss: 7.6473e-04
#
# Epoch 00033: val_loss did not improve from 0.00073
# Epoch 34/150
# 1712/1712 [==============================] - 0s 201us/step - loss: 2.4095e-04 - val_loss: 7.5141e-04
#
# Epoch 00034: val_loss did not improve from 0.00073
# Epoch 35/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 2.3521e-04 - val_loss: 7.4328e-04
#
# Epoch 00035: val_loss did not improve from 0.00073
# Epoch 36/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 2.3507e-04 - val_loss: 7.5543e-04
#
# Epoch 00036: val_loss did not improve from 0.00073
# Epoch 37/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 2.2367e-04 - val_loss: 7.2633e-04
#
# Epoch 00037: val_loss improved from 0.00073 to 0.00073, saving model to best_weights.h5
# Epoch 38/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 2.2148e-04 - val_loss: 7.3388e-04
#
# Epoch 00038: val_loss did not improve from 0.00073
# Epoch 39/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 2.1709e-04 - val_loss: 7.1670e-04
#
# Epoch 00039: val_loss improved from 0.00073 to 0.00072, saving model to best_weights.h5
# Epoch 40/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 2.0896e-04 - val_loss: 7.1202e-04
#
# Epoch 00040: val_loss improved from 0.00072 to 0.00071, saving model to best_weights.h5
# Epoch 41/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 2.1328e-04 - val_loss: 6.9783e-04
#
# Epoch 00041: val_loss improved from 0.00071 to 0.00070, saving model to best_weights.h5
# Epoch 42/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 2.0518e-04 - val_loss: 7.0725e-04
#
# Epoch 00042: val_loss did not improve from 0.00070
# Epoch 43/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 2.0407e-04 - val_loss: 6.9748e-04
#
# Epoch 00043: val_loss improved from 0.00070 to 0.00070, saving model to best_weights.h5
# Epoch 44/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 1.9919e-04 - val_loss: 7.1912e-04
#
# Epoch 00044: val_loss did not improve from 0.00070
# Epoch 45/150
# 1712/1712 [==============================] - 0s 201us/step - loss: 2.0356e-04 - val_loss: 7.0891e-04
#
# Epoch 00045: val_loss did not improve from 0.00070
# Epoch 46/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.9929e-04 - val_loss: 7.3293e-04
#
# Epoch 00046: val_loss did not improve from 0.00070
# Epoch 47/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.9646e-04 - val_loss: 7.4488e-04
#
# Epoch 00047: val_loss did not improve from 0.00070
# Epoch 48/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.8857e-04 - val_loss: 7.1385e-04
#
# Epoch 00048: val_loss did not improve from 0.00070
# Epoch 49/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.8972e-04 - val_loss: 7.1547e-04
#
# Epoch 00049: val_loss did not improve from 0.00070
# Epoch 50/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.8862e-04 - val_loss: 7.2484e-04
#
# Epoch 00050: val_loss did not improve from 0.00070
# Epoch 51/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 1.8440e-04 - val_loss: 7.3618e-04
#
# Epoch 00051: val_loss did not improve from 0.00070
# Epoch 52/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.7608e-04 - val_loss: 7.1197e-04
#
# Epoch 00052: val_loss did not improve from 0.00070
# Epoch 53/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.7685e-04 - val_loss: 7.6932e-04
#
# Epoch 00053: val_loss did not improve from 0.00070
# Epoch 54/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.7863e-04 - val_loss: 7.4715e-04
#
# Epoch 00054: val_loss did not improve from 0.00070
# Epoch 55/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 1.8553e-04 - val_loss: 7.0700e-04
#
# Epoch 00055: val_loss did not improve from 0.00070
# Epoch 56/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.7451e-04 - val_loss: 7.1528e-04
#
# Epoch 00056: val_loss did not improve from 0.00070
# Epoch 57/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.7266e-04 - val_loss: 7.4544e-04
#
# Epoch 00057: val_loss did not improve from 0.00070
# Epoch 58/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 1.6820e-04 - val_loss: 7.0452e-04
#
# Epoch 00058: val_loss did not improve from 0.00070
# Epoch 59/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 1.6728e-04 - val_loss: 7.2178e-04
#
# Epoch 00059: val_loss did not improve from 0.00070
# Epoch 60/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 1.6678e-04 - val_loss: 7.1413e-04
#
# Epoch 00060: val_loss did not improve from 0.00070
# Epoch 61/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 1.6078e-04 - val_loss: 7.1402e-04
#
# Epoch 00061: val_loss did not improve from 0.00070
# Epoch 62/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.5962e-04 - val_loss: 6.8805e-04
#
# Epoch 00062: val_loss improved from 0.00070 to 0.00069, saving model to best_weights.h5
# Epoch 63/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 1.5992e-04 - val_loss: 6.9300e-04
#
# Epoch 00063: val_loss did not improve from 0.00069
# Epoch 64/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 1.6241e-04 - val_loss: 6.8791e-04
#
# Epoch 00064: val_loss improved from 0.00069 to 0.00069, saving model to best_weights.h5
# Epoch 65/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 1.6109e-04 - val_loss: 6.8708e-04
#
# Epoch 00065: val_loss improved from 0.00069 to 0.00069, saving model to best_weights.h5
# Epoch 66/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.5926e-04 - val_loss: 7.1063e-04
#
# Epoch 00066: val_loss did not improve from 0.00069
# Epoch 67/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.4714e-04 - val_loss: 7.2334e-04
#
# Epoch 00067: val_loss did not improve from 0.00069
# Epoch 68/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 1.5492e-04 - val_loss: 7.4751e-04
#
# Epoch 00068: val_loss did not improve from 0.00069
# Epoch 69/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.5226e-04 - val_loss: 7.4377e-04
#
# Epoch 00069: val_loss did not improve from 0.00069
# Epoch 70/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.5041e-04 - val_loss: 7.1181e-04
#
# Epoch 00070: val_loss did not improve from 0.00069
# Epoch 71/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.4826e-04 - val_loss: 7.1141e-04
#
# Epoch 00071: val_loss did not improve from 0.00069
# Epoch 72/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.4670e-04 - val_loss: 7.0766e-04
#
# Epoch 00072: val_loss did not improve from 0.00069
# Epoch 73/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 1.3990e-04 - val_loss: 7.0802e-04
#
# Epoch 00073: val_loss did not improve from 0.00069
# Epoch 74/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.4316e-04 - val_loss: 7.1741e-04
#
# Epoch 00074: val_loss did not improve from 0.00069
# Epoch 75/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 1.4207e-04 - val_loss: 7.2580e-04
#
# Epoch 00075: val_loss did not improve from 0.00069
# Epoch 76/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.4202e-04 - val_loss: 7.1688e-04
#
# Epoch 00076: val_loss did not improve from 0.00069
# Epoch 77/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 1.4173e-04 - val_loss: 6.8854e-04
#
# Epoch 00077: val_loss did not improve from 0.00069
# Epoch 78/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.3943e-04 - val_loss: 6.6588e-04
#
# Epoch 00078: val_loss improved from 0.00069 to 0.00067, saving model to best_weights.h5
# Epoch 79/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.3582e-04 - val_loss: 7.0137e-04
#
# Epoch 00079: val_loss did not improve from 0.00067
# Epoch 80/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 1.3419e-04 - val_loss: 7.2637e-04
#
# Epoch 00080: val_loss did not improve from 0.00067
# Epoch 81/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 1.3693e-04 - val_loss: 7.1252e-04
#
# Epoch 00081: val_loss did not improve from 0.00067
# Epoch 82/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.4287e-04 - val_loss: 7.5997e-04
#
# Epoch 00082: val_loss did not improve from 0.00067
# Epoch 83/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 1.3431e-04 - val_loss: 7.1683e-04
#
# Epoch 00083: val_loss did not improve from 0.00067
# Epoch 84/150
# 1712/1712 [==============================] - 0s 218us/step - loss: 1.3262e-04 - val_loss: 6.8884e-04
#
# Epoch 00084: val_loss did not improve from 0.00067
# Epoch 85/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 1.3115e-04 - val_loss: 7.4175e-04
#
# Epoch 00085: val_loss did not improve from 0.00067
# Epoch 86/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 1.3113e-04 - val_loss: 7.1952e-04
#
# Epoch 00086: val_loss did not improve from 0.00067
# Epoch 87/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 1.2925e-04 - val_loss: 6.9274e-04
#
# Epoch 00087: val_loss did not improve from 0.00067
# Epoch 88/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 1.2364e-04 - val_loss: 7.1304e-04
#
# Epoch 00088: val_loss did not improve from 0.00067
# Epoch 89/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 1.2562e-04 - val_loss: 6.8689e-04
#
# Epoch 00089: val_loss did not improve from 0.00067
# Epoch 90/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 1.2728e-04 - val_loss: 7.1424e-04
#
# Epoch 00090: val_loss did not improve from 0.00067
# Epoch 91/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.2685e-04 - val_loss: 6.9665e-04
#
# Epoch 00091: val_loss did not improve from 0.00067
# Epoch 92/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.2509e-04 - val_loss: 7.0765e-04
#
# Epoch 00092: val_loss did not improve from 0.00067
# Epoch 93/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.2738e-04 - val_loss: 6.9221e-04
#
# Epoch 00093: val_loss did not improve from 0.00067
# Epoch 94/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 1.2235e-04 - val_loss: 6.7715e-04
#
# Epoch 00094: val_loss did not improve from 0.00067
# Epoch 95/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.1838e-04 - val_loss: 7.3849e-04
#
# Epoch 00095: val_loss did not improve from 0.00067
# Epoch 96/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.2253e-04 - val_loss: 7.0767e-04
#
# Epoch 00096: val_loss did not improve from 0.00067
# Epoch 97/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 1.1936e-04 - val_loss: 7.2438e-04
#
# Epoch 00097: val_loss did not improve from 0.00067
# Epoch 98/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 1.1476e-04 - val_loss: 6.9083e-04
#
# Epoch 00098: val_loss did not improve from 0.00067
# Epoch 99/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.1876e-04 - val_loss: 7.2895e-04
#
# Epoch 00099: val_loss did not improve from 0.00067
# Epoch 100/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.1810e-04 - val_loss: 7.2844e-04
#
# Epoch 00100: val_loss did not improve from 0.00067
# Epoch 101/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.1758e-04 - val_loss: 6.8038e-04
#
# Epoch 00101: val_loss did not improve from 0.00067
# Epoch 102/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 1.1326e-04 - val_loss: 6.7186e-04
#
# Epoch 00102: val_loss did not improve from 0.00067
# Epoch 103/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 1.1508e-04 - val_loss: 7.2054e-04
#
# Epoch 00103: val_loss did not improve from 0.00067
# Epoch 104/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.1509e-04 - val_loss: 7.1618e-04
#
# Epoch 00104: val_loss did not improve from 0.00067
# Epoch 105/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 1.1256e-04 - val_loss: 7.1951e-04
#
# Epoch 00105: val_loss did not improve from 0.00067
# Epoch 106/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 1.1280e-04 - val_loss: 6.8671e-04
#
# Epoch 00106: val_loss did not improve from 0.00067
# Epoch 107/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 1.1241e-04 - val_loss: 6.9204e-04
#
# Epoch 00107: val_loss did not improve from 0.00067
# Epoch 108/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.1269e-04 - val_loss: 6.8262e-04
#
# Epoch 00108: val_loss did not improve from 0.00067
# Epoch 109/150
# 1712/1712 [==============================] - 0s 201us/step - loss: 1.0895e-04 - val_loss: 7.3334e-04
#
# Epoch 00109: val_loss did not improve from 0.00067
# Epoch 110/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.0756e-04 - val_loss: 7.1181e-04
#
# Epoch 00110: val_loss did not improve from 0.00067
# Epoch 111/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.0684e-04 - val_loss: 7.2218e-04
#
# Epoch 00111: val_loss did not improve from 0.00067
# Epoch 112/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 1.0475e-04 - val_loss: 7.0520e-04
#
# Epoch 00112: val_loss did not improve from 0.00067
# Epoch 113/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 1.0584e-04 - val_loss: 6.9576e-04
#
# Epoch 00113: val_loss did not improve from 0.00067
# Epoch 114/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 1.0725e-04 - val_loss: 7.5560e-04
#
# Epoch 00114: val_loss did not improve from 0.00067
# Epoch 115/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 1.0569e-04 - val_loss: 6.9892e-04
#
# Epoch 00115: val_loss did not improve from 0.00067
# Epoch 116/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 1.0463e-04 - val_loss: 7.1860e-04
#
# Epoch 00116: val_loss did not improve from 0.00067
# Epoch 117/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 1.0345e-04 - val_loss: 7.0277e-04
#
# Epoch 00117: val_loss did not improve from 0.00067
# Epoch 118/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 1.0467e-04 - val_loss: 7.4541e-04
#
# Epoch 00118: val_loss did not improve from 0.00067
# Epoch 119/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 1.0418e-04 - val_loss: 7.3733e-04
#
# Epoch 00119: val_loss did not improve from 0.00067
# Epoch 120/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 1.0397e-04 - val_loss: 7.1897e-04
#
# Epoch 00120: val_loss did not improve from 0.00067
# Epoch 121/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.0434e-04 - val_loss: 7.0716e-04
#
# Epoch 00121: val_loss did not improve from 0.00067
# Epoch 122/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 1.0093e-04 - val_loss: 7.2279e-04
#
# Epoch 00122: val_loss did not improve from 0.00067
# Epoch 123/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 1.0505e-04 - val_loss: 7.2918e-04
#
# Epoch 00123: val_loss did not improve from 0.00067
# Epoch 124/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 9.8402e-05 - val_loss: 7.2213e-04
#
# Epoch 00124: val_loss did not improve from 0.00067
# Epoch 125/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 9.4495e-05 - val_loss: 7.2901e-04
#
# Epoch 00125: val_loss did not improve from 0.00067
# Epoch 126/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 9.8880e-05 - val_loss: 6.9080e-04
#
# Epoch 00126: val_loss did not improve from 0.00067
# Epoch 127/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 9.7460e-05 - val_loss: 7.1355e-04
#
# Epoch 00127: val_loss did not improve from 0.00067
# Epoch 128/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 1.0015e-04 - val_loss: 7.1406e-04
#
# Epoch 00128: val_loss did not improve from 0.00067
# Epoch 129/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 9.8422e-05 - val_loss: 7.4041e-04
#
# Epoch 00129: val_loss did not improve from 0.00067
# Epoch 130/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 9.9917e-05 - val_loss: 6.8944e-04
#
# Epoch 00130: val_loss did not improve from 0.00067
# Epoch 131/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 9.5307e-05 - val_loss: 7.0102e-04
#
# Epoch 00131: val_loss did not improve from 0.00067
# Epoch 132/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 9.7451e-05 - val_loss: 7.1745e-04
#
# Epoch 00132: val_loss did not improve from 0.00067
# Epoch 133/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 9.7096e-05 - val_loss: 7.3193e-04
#
# Epoch 00133: val_loss did not improve from 0.00067
# Epoch 134/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 9.6205e-05 - val_loss: 7.3140e-04
#
# Epoch 00134: val_loss did not improve from 0.00067
# Epoch 135/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 9.4707e-05 - val_loss: 7.0683e-04
#
# Epoch 00135: val_loss did not improve from 0.00067
# Epoch 136/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 9.4532e-05 - val_loss: 7.1105e-04
#
# Epoch 00136: val_loss did not improve from 0.00067
# Epoch 137/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 9.0725e-05 - val_loss: 7.2256e-04
#
# Epoch 00137: val_loss did not improve from 0.00067
# Epoch 138/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 9.0252e-05 - val_loss: 7.1438e-04
#
# Epoch 00138: val_loss did not improve from 0.00067
# Epoch 139/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 8.9141e-05 - val_loss: 7.2917e-04
#
# Epoch 00139: val_loss did not improve from 0.00067
# Epoch 140/150
# 1712/1712 [==============================] - 0s 218us/step - loss: 9.0329e-05 - val_loss: 7.1279e-04
#
# Epoch 00140: val_loss did not improve from 0.00067
# Epoch 141/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 9.0939e-05 - val_loss: 7.3221e-04
#
# Epoch 00141: val_loss did not improve from 0.00067
# Epoch 142/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 9.2171e-05 - val_loss: 7.3474e-04
#
# Epoch 00142: val_loss did not improve from 0.00067
# Epoch 143/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 9.4547e-05 - val_loss: 7.0945e-04
#
# Epoch 00143: val_loss did not improve from 0.00067
# Epoch 144/150
# 1712/1712 [==============================] - 0s 254us/step - loss: 8.9492e-05 - val_loss: 7.3754e-04
#
# Epoch 00144: val_loss did not improve from 0.00067
# Epoch 145/150
# 1712/1712 [==============================] - 1s 345us/step - loss: 9.0461e-05 - val_loss: 6.8973e-04
#
# Epoch 00145: val_loss did not improve from 0.00067
# Epoch 146/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 9.4364e-05 - val_loss: 6.9122e-04
#
# Epoch 00146: val_loss did not improve from 0.00067
# Epoch 147/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 8.8566e-05 - val_loss: 7.2604e-04
#
# Epoch 00147: val_loss did not improve from 0.00067
# Epoch 148/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 8.7054e-05 - val_loss: 7.1029e-04
#
# Epoch 00148: val_loss did not improve from 0.00067
# Epoch 149/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 9.0424e-05 - val_loss: 7.3475e-04
#
# Epoch 00149: val_loss did not improve from 0.00067
# Epoch 150/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 8.8589e-05 - val_loss: 7.0034e-04
#
# Epoch 00150: val_loss did not improve from 0.00067

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
